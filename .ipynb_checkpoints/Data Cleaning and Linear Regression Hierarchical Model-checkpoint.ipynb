# %% [markdown]
# # Data Cleaning and Linear Regression Hierarchical Predicting

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import time
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %% [markdown]
# ### Data Cleaning

# %%
# import data file downloaded from Crunchbase database
crunchbasedf = pd.read_csv('crunchbase_export.csv')

# import list of companies that we did sentiment analysis on
companies_list = pd.read_csv('companies.csv').company.tolist()

# make all company names lowercase for easier comparison
companies_list = [x.lower() for x in companies_list]
lowercase = lambda x: str(x).lower()
crunchbasedf.name = crunchbasedf.name.apply(lowercase)

# %%
# create formatter that changes string into proper format 
# (for some reason, the data in crunchbasedf is formatted 
# really weirdly, requiring me to do this)

def formatter(string):
    space = False
    formatted = ""
    for s in string:
        if space and (s is not ' '):
            formatted += s
        elif s == ' ':
            space = True
    return formatted

# %%
# ************************************************ #
# CREATE DATAFRAME WITH ONLY THE COMPANIES WE NEED #
# ************************************************ #

# declare lists of relevant demographics data we will be using
first_funding_date = []
last_funding_date = []
funding_total = []
founded_date = []
public = []
funding_rounds = []
new_companies_list = []

# iterate through list of companies to extract information for each companies
for company in companies_list:
    # check if company is in crunchbasedf
    if company in crunchbasedf.name.tolist():
        # only include companies in crunchbasedf
        new_companies_list.append(company)
        
        # create public variable
        if formatter(crunchbasedf[crunchbasedf.name==company].status.to_string()).strip() == "ipo":
            public.append(1)
        else:
            public.append(0)

        # create funding rounds variable
        funding_rounds.append(int(formatter(crunchbasedf[crunchbasedf.name==company].funding_rounds.to_string()).strip()))

        # create total funds variable
        funding_total.append(int(formatter(crunchbasedf[crunchbasedf.name==company][' funding_total_usd '].to_string()).replace(",","").strip()))

        # create last funding date variable
        last_funding_date.append(crunchbasedf[crunchbasedf.name==company].last_funding_at.to_string()[-10:])

        # create first funding date variable
        first_funding_date.append(crunchbasedf[crunchbasedf.name==company].first_funding_at.to_string()[-10:])

        # create founded date variable
        founded_date.append(crunchbasedf[crunchbasedf.name==company].founded_at.to_string()[-10:])

# create dictionary with all 
dfdict = {'company':new_companies_list,'first_funding_date':first_funding_date,'last_funding_date':last_funding_date,
          'funding_total':funding_total,'founded_date':founded_date,'public':public,'funding_rounds':funding_rounds}

# %%
# convert dictionary into pandas dataframe
infodf = pd.DataFrame.from_dict(dfdict)

# added founded date for Vivint, since Cruchbase didn't have it (found on Wikipedia)
infodf.loc[33,'founded_date'] = '1997-06-01'

# change strings into date items to calculate company age and time since last funding
infodf.first_funding_date = infodf.first_funding_date.apply(pd.datetools.parse)
infodf.last_funding_date = infodf.last_funding_date.apply(pd.datetools.parse)
infodf.founded_date = infodf.founded_date.apply(pd.datetools.parse)

infodf
# Out:
#                   company first_funding_date founded_date  funding_rounds  funding_total last_funding_date  public
# 0                facebook         2004-09-01   2004-02-04              11     2425700000        2011-01-21       1
# 1                  google         1998-08-01   1998-09-07               3       26100000        1999-06-07       1
# 2                   apple         1977-05-15   1976-04-01               1         250000        1977-05-15       1
# 3                  amazon         1995-07-01   1994-07-05               1        8000000        1995-07-01       1
# 4                    uber         2009-08-01   2009-03-01              13     8207450000        2015-09-07       0
# 5                    lyft         2009-06-01   2012-01-01               8     1012500000        2015-05-15       0
# 6                  airbnb         2009-01-01   2008-08-01               8     2394820000        2015-11-20       0
# 7                  fitbit         2008-10-10   2007-05-01               4       66000000        2013-08-13       1
# 8                 jawbone         2006-12-15   1999-01-01              12      818799995        2015-04-30       0
# 9                coursera         2012-04-18   2012-01-01               6      146100000        2015-10-27       0
# 10           athenahealth         1999-10-01   1997-01-01               3       40000000        2004-04-23       1
# 11                twitter         2007-07-01   2006-03-21               8     1160166511        2011-09-08       1
# 12               snapchat         2012-05-01   2011-05-01               8     1185585000        2015-05-29       0
# 13                dropbox         2007-06-01   2007-06-01               6     1107215000        2014-04-06       0
# 14                spotify         2008-10-01   2006-07-14              11     1063779080        2015-08-30       0
# 15                 zocdoc         2008-08-18   2007-09-18               4      223000000        2015-08-20       0
# 16                  asana         2008-09-01   2009-01-01               4       38200000        2012-07-23       0
# 17               linkedin         2003-11-01   2003-05-05               5      103200000        2008-10-22       1
# 18                  oscar         2013-07-19   2013-07-01               5      327500000        2015-09-15       0
# 19             chartboost         2011-10-01   2011-02-01               3       21000000        2015-03-01       0
# 20                groupon         2007-01-01   2008-11-11               6     1137000000        2011-02-25       1
# 21                wayfair         2011-06-21   2002-08-01               3      358000000        2014-03-07       1
# 22              instagram         2010-03-05   2010-06-02               3       57500000        2012-04-05       0
# 23               buzzfeed         2008-07-09   2006-01-01               6      296300000        2015-08-18       0
# 24              pinterest         2010-01-01   2009-01-01              10     1315500000        2015-06-01       0
# 25  palantir technologies         2005-09-01   2004-01-01              16     1671557162        2015-10-21       0
# 26                  kayak         2004-01-01   2004-01-14               6      235024070        2012-08-17       0
# 27                grubhub         2007-11-01   2004-01-01               6       84100000        2013-08-21       1
# 28                    box         2005-09-01   2005-01-01              11      558950000        2014-07-01       1
# 29                hubspot         2006-05-01   2006-06-09               6      100500000        2012-11-10       1
# 30                 square         2009-11-01   2009-02-01               9      590500000        2015-04-01       1
# 31               appnexus         2007-12-27   2007-09-01               8      288171856        2015-04-15       0
# 32                  quora         2010-03-28   2009-06-01               3      141000000        2014-04-09       0
# 33                 vivint         2010-10-04   1997-06-01               1      565000000        2010-10-04       0
# 34             riot games         2008-07-10   2007-03-15               2       15000000        2009-09-09       0
# 35                yik yak         2014-04-22   2013-10-10               3       73500000        2014-11-24       0
# 36       misfit wearables         2011-11-23   2011-10-05               5       64396675        2014-12-02       0
# 37               doordash         2013-03-01   2013-01-01               4       59700000        2015-03-26       0
# 38               birchbox         2010-10-27   2010-01-01               3       71900000        2014-04-21       0
# 39                  slack         2009-01-01   2013-01-01               7      339950000        2015-04-16       0
# 40            gilt groupe         2007-11-01   2007-01-01               7      286000000        2015-02-16       0
# 41                 github         2012-07-09   2008-02-29               2      350000000        2015-07-29       0
# 42               zenefits         2013-07-26   2013-01-01               4      583600000        2015-05-06       0

# %%
# calculate age and time since last funding
import datetime
today = datetime.datetime(2015, 12, 10)
infodf['age'] = (today - infodf['founded_date']).values / np.timedelta64(1, 'D')
infodf['time_from_last_funding'] = (today - infodf['last_funding_date']).values / np.timedelta64(1, 'D')
infodf.head()
# Out:
#     company first_funding_date founded_date  funding_rounds  funding_total last_funding_date  public    age  time_from_last_funding
# 0  facebook         2004-09-01   2004-02-04              11     2425700000        2011-01-21       1   4327                    1784
# 1    google         1998-08-01   1998-09-07               3       26100000        1999-06-07       1   6303                    6030
# 2     apple         1977-05-15   1976-04-01               1         250000        1977-05-15       1  14497                   14088
# 3    amazon         1995-07-01   1994-07-05               1        8000000        1995-07-01       1   7828                    7467
# 4      uber         2009-08-01   2009-03-01              13     8207450000        2015-09-07       0   2475                      94

# %%
# convert csv's with sentiment predictions into pandas dataframes
bin_pred = pd.read_csv('company_with_predictions.csv')
range_pred = pd.read_csv('company_with_prediction_range.csv')

# drop first column (index column)
bin_pred = bin_pred.drop(bin_pred.columns[[0]], axis=1)
range_pred = range_pred.drop(range_pred.columns[[0]], axis=1)

# change name of column from 'name' to 'company' to allow dataframe to merge with infodf in next step
bin_pred = bin_pred.rename(columns={'name': 'company'})
range_pred = range_pred.rename(columns={'name': 'company'})

# make company names lowercase to allow for successful merge with infodf
bin_pred.company = bin_pred.company.apply(lowercase)
range_pred.company = range_pred.company.apply(lowercase)
range_pred
# Out:
#     weighted_predict_range     company  predict_range
# 0                -0.360254      airbnb      -0.258098
# 1                -0.232692      amazon      -0.120673
# 2                 0.055762       apple      -0.063874
# 3                -0.067395       asana      -0.067395
# 4                 0.000000    buzzfeed       0.013944
# 5                -0.445005    coursera      -0.445005
# 6                -0.218946    doordash       0.010715
# 7                 0.374347     dropbox       0.130647
# 8                 0.197082      fitbit      -0.045225
# 9                 1.106542      google      -0.019686
# 10                0.036219     hubspot       0.018503
# 11                0.049395   instagram       0.076848
# 12               -0.451950     jawbone      -0.451950
# 13                0.010870       kayak       0.010870
# 14               -1.823318  laserfiche      -0.911659
# 15                0.159934    linkedin      -0.115931
# 16               -0.432146        lyft      -0.263680
# 17               -0.129865   microsoft      -0.044644
# 18                0.934466   pinterest       0.934466
# 19                0.016985       quora       0.016985
# 20               -0.455875  riot games      -1.371271
# 21                0.070305    snapchat       0.076418
# 22               -0.339114     spotify      -0.019935
# 23                1.274349      tinder      -0.021612
# 24               -0.037151     twitter      -0.039241
# 25                0.143321        uber       0.065317
# 26                0.021509      vivint       0.018753
# 27                0.017672     yik yak      -0.074685

# %%
# merge sentiment data with demographics data
tempdf = pd.merge(infodf,bin_pred,how='inner',on=['company'])
newdf = pd.merge(tempdf,range_pred,how='inner',on=['company'])

# drop unnecessary columns
newdf = newdf.drop(['company','first_funding_date','founded_date','last_funding_date',], 1)
newdf
# Out:
#     funding_rounds  funding_total  public    age  time_from_last_funding  weighted_predict  predict_binary  weighted_predict_range  predict_range
# 0                3       26100000       1   6303                    6030         -0.612903       -0.058065                1.106542      -0.019686
# 1                1         250000       1  14497                   14088         -1.156124       -0.067295                0.055762      -0.063874
# 2                1        8000000       1   7828                    7467         -0.246377       -0.144928               -0.232692      -0.120673
# 3               13     8207450000       0   2475                      94          0.162162        0.162162                0.143321       0.065317
# 4                8     1012500000       0   1439                     209         -0.383562       -0.150685               -0.432146      -0.263680
# 5                8     2394820000       0   2687                      20         -0.176471        0.117647               -0.360254      -0.258098
# 6                4       66000000       1   3145                     849          0.081967        0.131148                0.197082      -0.045225
# 7               12      818799995       0   6187                     224         -2.000000       -2.000000               -0.451950      -0.451950
# 8                6      146100000       0   1439                      44          0.000000        0.000000               -0.445005      -0.445005
# 9                8     1160166511       1   3551                    1554         -0.411765       -0.176471               -0.037151      -0.039241
# 10               8     1185585000       0   1684                     195          0.012821        0.025641                0.070305       0.076418
# 11               6     1107215000       0   3114                     613          0.750000        0.250000                0.374347       0.130647
# 12              11     1063779080       0   3436                     102         -0.217949        0.000000               -0.339114      -0.019935
# 13               4       38200000       0   2534                    1235          1.000000        1.000000               -0.067395      -0.067395
# 14               5      103200000       1   4602                    2605         -0.285714       -0.142857                0.159934      -0.115931
# 15               3       57500000       0   2017                    1344          0.032609        0.076087                0.049395       0.076848
# 16               6      296300000       0   3630                     114          0.000000       -2.000000                0.000000       0.013944
# 17              10     1315500000       0   2534                     192          1.000000        1.000000                0.934466       0.934466
# 18               6      235024070       0   4348                    1210         -1.500000       -1.500000                0.010870       0.010870
# 19               6      100500000       1   3471                    1125          0.000000        0.000000                0.036219       0.018503
# 20               3      141000000       0   2383                     610          0.000000        0.000000                0.016985       0.016985
# 21               1      565000000       0   6766                    1893          0.000000        0.000000                0.021509       0.018753
# 22               2       15000000       0   3192                    2283         -1.000000       -2.000000               -0.455875      -1.371271
# 23               3       73500000       0    791                     381          0.200000        0.200000                0.017672      -0.074685
# 24               4       59700000       0   1073                     259         -0.500000       -0.250000               -0.218946       0.010715

# %% [markdown]
# ### EDA

# %% [markdown]
# Let's do some EDA to see the distribution of our data. We first created histograms of all the variables to see what each distribution looked like.

# %%
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(30, 30), tight_layout=True)
predictors = ['funding_total','funding_rounds','age','time_from_last_funding',
              'weighted_predict','predict_binary','weighted_predict_range','predict_range']
for ax, c in zip(axes.ravel(), predictors):
    ax.hist(newdf[c],bins=15,label=c)
    ax.set_xlabel(c)
    ax.set_ylabel("# of companies")

# %% [markdown]
# We then test for linearity between each feature variable and the response variable. We do this by creating a scatter plot for each feature against the response variable.

# %%
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(30, 30), tight_layout=True)
predictors = ['funding_rounds','age','time_from_last_funding','weighted_predict',
              'predict_binary','weighted_predict_range','predict_range']
for ax, c in zip(axes.ravel(), predictors):
    ax.scatter(newdf[c],newdf.funding_total,s=75,)
    ax.set_xlabel(c)
    ax.set_ylabel('total funding')

# %% [markdown]
# From looking at both our histograms, we see that most variables approximate to normality, but some are heavily right skewed. Additionally, the scatter plots show us that the graphs seem to somewhat approximate linearity.
#
# To fix the skewedness, we do a simple log transformation on the variables that are skewed (we only log transform the predictor variables and not the response variable because transforming the response variable makes it a lot harder to interpret the results)

# %%
# logging the skew data (based on the histograms from above)
newdf['log_age'] = newdf.age.apply(np.log)
newdf['log_time_from_last_funding'] =  newdf.time_from_last_funding.apply(np.log)
newdf = newdf1.drop(['age','time_from_last_funding'], 1)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(30, 10), tight_layout=True)
axes[0].hist(newdf.log_age,bins=15)
axes[0].set_xlabel("log(age)")
axes[0].set_ylabel("# of companies")
axes[1].hist(newdf.log_time_from_last_funding,bins=15)
axes[1].set_xlabel("log(time from last funding round)")
axes[1].set_ylabel("# of companies")

# %% [markdown]
# Our variables are much more normal now, which allows us to conduct a linear regression.

# %% [markdown]
# ### Model Creation

# %% [markdown]
# Let's try creating a linear regression model. First we try an ordinary least squares regression.

# %%
import statsmodels.api as sm
from statsmodels.formula.api import glm, ols

# %%
ols_model1 = ols('funding_total ~ log_time_from_last_funding + log_age + public + funding_rounds + weighted_predict + predict_binary', newdf).fit()
ols_model2 = ols('funding_total ~ log_time_from_last_funding + log_age + public + funding_rounds + weighted_predict_range + predict_range', newdf).fit()

# %%
ols_model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          funding_total   R-squared:                       0.458
# Model:                            OLS   Adj. R-squared:                  0.277
# Method:                 Least Squares   F-statistic:                     2.532
# Date:                Thu, 10 Dec 2015   Prob (F-statistic):             0.0590
# Time:                        22:06:43   Log-Likelihood:                -558.01
# No. Observations:                  25   AIC:                             1130.
# Df Residuals:                      18   BIC:                             1139.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------
# Intercept                  -4.182e+09    4.6e+09     -0.910      0.375     -1.38e+10  5.47e+09
# log_time_from_last_funding   3.69e+07   3.67e+08      0.101      0.921     -7.33e+08  8.07e+08
# log_age                     3.982e+08    6.5e+08      0.613      0.548     -9.67e+08  1.76e+09
# public                     -4.995e+08   9.03e+08     -0.553      0.587      -2.4e+09   1.4e+09
# funding_rounds              3.193e+08   1.29e+08      2.478      0.023      4.86e+07   5.9e+08
# weighted_predict            2.147e+08   7.01e+08      0.306      0.763     -1.26e+09  1.69e+09
# predict_binary              3.348e+08   5.86e+08      0.571      0.575     -8.97e+08  1.57e+09
# ==============================================================================
# Omnibus:                       34.074   Durbin-Watson:                   1.620
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               98.656
# Skew:                           2.453   Prob(JB):                     3.78e-22
# Kurtosis:                      11.405   Cond. No.                         195.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
ols_model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          funding_total   R-squared:                       0.426
# Model:                            OLS   Adj. R-squared:                  0.235
# Method:                 Least Squares   F-statistic:                     2.230
# Date:                Thu, 10 Dec 2015   Prob (F-statistic):             0.0875
# Time:                        22:06:51   Log-Likelihood:                -558.72
# No. Observations:                  25   AIC:                             1131.
# Df Residuals:                      18   BIC:                             1140.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------
# Intercept                  -1.779e+09   4.34e+09     -0.410      0.687     -1.09e+10  7.34e+09
# log_time_from_last_funding -4.741e+07   3.88e+08     -0.122      0.904     -8.63e+08  7.69e+08
# log_age                     1.508e+08    6.3e+08      0.239      0.813     -1.17e+09  1.47e+09
# public                     -3.085e+08   8.93e+08     -0.346      0.734     -2.18e+09  1.57e+09
# funding_rounds              3.035e+08   1.34e+08      2.270      0.036      2.26e+07  5.84e+08
# weighted_predict_range      7.842e+08   1.16e+09      0.676      0.508     -1.65e+09  3.22e+09
# predict_range              -4.415e+08   1.15e+09     -0.382      0.707     -2.87e+09  1.98e+09
# ==============================================================================
# Omnibus:                       34.201   Durbin-Watson:                   1.571
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               97.530
# Skew:                           2.480   Prob(JB):                     6.63e-22
# Kurtosis:                      11.308   Cond. No.                         179.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Because our R^2 values are really poor, we try using a forward stepwise regression to choose only the variables that have the highest explanatory power. Code is from http://planspace.org/20150423-forward_selection_with_statsmodels/

# %%
import statsmodels.formula.api as smf

def forward_selected(data, response):
    """Linear model designed by forward selection.

    Parameters:
    -----------
    data : pandas DataFrame with all possible predictors and response

    response: string, name of response column in data

    Returns:
    --------
    model: an "optimal" fitted statsmodels linear model
           with an intercept
           selected by forward selection
           evaluated by adjusted R-squared
    """
    remaining = set(data.columns)
    remaining.remove(response)
    selected = []
    current_score, best_new_score = 0.0, 0.0
    while remaining and current_score == best_new_score:
        scores_with_candidates = []
        for candidate in remaining:
            formula = "{} ~ {} + 1".format(response,
                                           ' + '.join(selected + [candidate]))
            score = smf.ols(formula, data).fit().rsquared_adj
            scores_with_candidates.append((score, candidate))
        scores_with_candidates.sort()
        best_new_score, best_candidate = scores_with_candidates.pop()
        if current_score < best_new_score:
            remaining.remove(best_candidate)
            selected.append(best_candidate)
            current_score = best_new_score
    formula = "{} ~ {} + 1".format(response,
                                   ' + '.join(selected))
    model = smf.ols(formula, data).fit()
    return model

# %%
newdf1 = newdf.drop(['predict_binary','weighted_predict'], 1)
newdf2 = newdf.drop(['predict_range','weighted_predict_range'], 1)

# %%
ols_for_model1 = forward_selected(newdf1, 'funding_total')
ols_for_model2 = forward_selected(newdf2, 'funding_total')

# %%
ols_for_model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          funding_total   R-squared:                       0.408
# Model:                            OLS   Adj. R-squared:                  0.382
# Method:                 Least Squares   F-statistic:                     15.86
# Date:                Thu, 10 Dec 2015   Prob (F-statistic):           0.000588
# Time:                        22:07:37   Log-Likelihood:                -559.11
# No. Observations:                  25   AIC:                             1122.
# Df Residuals:                      23   BIC:                             1125.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# Intercept      -9.537e+08   5.13e+08     -1.858      0.076     -2.02e+09  1.08e+08
# funding_rounds  3.101e+08   7.79e+07      3.982      0.001      1.49e+08  4.71e+08
# ==============================================================================
# Omnibus:                       35.628   Durbin-Watson:                   1.743
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              107.732
# Skew:                           2.576   Prob(JB):                     4.04e-24
# Kurtosis:                      11.768   Cond. No.                         13.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
ols_for_model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          funding_total   R-squared:                       0.438
# Model:                            OLS   Adj. R-squared:                  0.386
# Method:                 Least Squares   F-statistic:                     8.556
# Date:                Thu, 10 Dec 2015   Prob (F-statistic):            0.00178
# Time:                        22:07:40   Log-Likelihood:                -558.47
# No. Observations:                  25   AIC:                             1123.
# Df Residuals:                      22   BIC:                             1127.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# Intercept      -8.911e+08   5.15e+08     -1.730      0.098     -1.96e+09  1.77e+08
# funding_rounds  3.129e+08   7.77e+07      4.029      0.001      1.52e+08  4.74e+08
# predict_binary  3.553e+08   3.31e+08      1.072      0.295     -3.32e+08  1.04e+09
# ==============================================================================
# Omnibus:                       35.259   Durbin-Watson:                   1.722
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              101.670
# Skew:                           2.582   Prob(JB):                     8.37e-23
# Kurtosis:                      11.422   Cond. No.                         13.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# This isn't a significant improvement, although the R^2 values are better. This is because the only variable that shows up as significant is the funding_rounds variable, which does not really give us much insight about the other variables since it's pretty obvious that funding rounds is correlated to total fundings.
#
# Instead, we will try using a different method. Here we will use a Random Forest Regressor and see how well it predicts the total funding.

# %%
y = log_newdf1.funding_total
X1 = log_newdf1.drop(['funding_total'],1)
X2 = log_newdf2.drop(['funding_total'],1)

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
forest_model1 = model.fit(X1,y)
forest_model2 = model.fit(X2,y)

# %%
forest_model1.score(X1,y)
# Out:
# 0.84371932249268322

# %%
forest_model2.score(X2,y)
# Out:
# 0.84836362743258298

# %% [markdown]
# Our R^2 value has significantly improved. At this time, we cannot determine whether this is simply due to overfitting, since we do not have enough data to split between testing and training value. However, this does show promise for having potential predictive power.
